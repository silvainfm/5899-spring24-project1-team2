# %% [markdown]
# # EDA

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# ### Cleaned date dataset

# %%
# Load the dataset
file_path = 'finished_annotation_5.2k.xlsx'
data = pd.read_excel(file_path)

# Display the first few rows of the dataframe to understand its structure, especially the 'pubDate' column
data.head()
# Out:
#    index                                    title & content
# 0  12024  Delays Won‚Äôt Hurt Japan‚Äôs First Ca...  \
# 1  20675  MetLife (MET) Could Be a Great Choice - Gettin...
# 2  33685  New York Cements Itself as the Gold Mining Cap...
# 3  12072  Shareholders v. Tesla, Nasdaq's diversity rule...
# 4  28164  CFOs Boost Currency Protections, Extend Hedge ...
#
#                                    sentiment_perigon
# 0  {'positive': 0.026093118, 'negative': 0.923414...  \
# 1  {'positive': 0.8553927, 'negative': 0.01334850...
# 2  {'positive': 0.46477953, 'negative': 0.0338994...
# 3  {'positive': 0.02043453, 'negative': 0.6323841...
# 4  {'positive': 0.031100325, 'negative': 0.955758...
#
#                                              summary
# 0  Osaka Governor Hirofumi Yoshimura said that th...  \
# 1  MetLife (MET) is a Finance stock that has seen...
# 2  This week, top-five producer AngloGold Ashanti...
# 3  \n\nThe case is In re Tesla Inc Securities Lit...
# 4  CFOs Boost Currency Protections, Extend Hedge ...
#
#                                          description Ticker
# 0  Years of delay to plans for Japan‚Äôs firs...    MGM  \
# 1  Dividends are one of the best benefits to bein...    MET
# 2  (Bloomberg) -- The momentum has been building ...    NEM
# 3  Some of the biggest securities cases of 2023 a...   NDAQ
# 4  Coca-Cola, Kimberly-Clark and Prologis are amo...     KO
#
#                               Sector                        Industry
# 0                           Services                Casinos & Gaming  \
# 1                         Financials                       Insurance
# 2  Extractives & Minerals Processing                 Metals & Mining
# 3                         Financials  Security & Commodity Exchanges
# 4                    Food & Beverage         Non-Alcoholic Beverages
#
#                      Company
# 0  MGM Resorts International  \
# 1                Metlife Inc
# 2               Newmont Corp
# 3                 Nasdaq Inc
# 4               Coca-Cola Co
#
#                                                 SASB  ... pubDate_brief
# 0  {'Internal Controls on Money Laundering': 'By ...  ...    2023-05-18  \
# 1  {'Financed Emissions': 'Entities participating...  ...    2022-10-31
# 2  {'Tailings Storage Facilities Management': 'Th...  ...    2023-02-08
# 3  {'Managing Conflicts of Interest': 'Security a...  ...    2023-05-18
# 4  {'Water Management': 'Water management relates...  ...    2023-05-04
#
#                      pubDate
# 0  2023-05-18T21:25:29+00:00  \
# 1  2022-10-31T20:36:25+00:00
# 2  2023-02-08T22:16:21+00:00
# 3  2023-05-18T14:28:52+00:00
# 4  2023-05-04T23:39:33+00:00
#
#                                                  url
# 0  https://www.dailymail.co.uk/health/article-121...  \
# 1  https://nypost.com/2022/10/31/lottery-app-jack...
# 2  https://www.newsmax.com/newsmax-tv/fitzgerald-...
# 3  https://www.axios.com/pro/media-deals/2023/05/...
# 4  https://www.cnbc.com/2023/05/04/apples-q2-ease...
#
#                                             keywords              categories
# 0  [{'name': 'identifiable user health informatio...    [{'name': 'Health'}]  \
# 1  [{'name': 'ticket sales', 'weight': 0.10697382...                      []
# 2  [{'name': 'Newsmax', 'weight': 0.09317307}, {'...  [{'name': 'Politics'}]
# 3  [{'name': 'Google AI', 'weight': 0.09959001}, ...      [{'name': 'Tech'}]
# 4  [{'name': 'last year', 'weight': 0.0876609}, {...      [{'name': 'Tech'}]
#
#                                             entities
# 0  [{'data': 'Chinese', 'type': 'NORP', 'mentions...  \
# 1  [{'data': 'Powerball', 'type': 'WORK_OF_ART', ...
# 2  [{'data': 'Fitzgerald', 'type': 'PERSON', 'men...
# 3  [{'data': 'YouTube', 'type': 'ORG', 'mentions'...
# 4  [{'data': 'Apple', 'type': 'ORG', 'mentions': ...
#
#                                              content
# 0  A popular fertility app used by women to track...  \
# 1  You could win Monday night’s historic $1 bil...
# 2  Rep. Scott Fitzgerald, R-Wis., told Newsmax We...
# 3  YouTube has embraced AI for causing a massive ...
# 4  Apple (AAPL) posted a better-than-expected Mar...
#
#                           articleId
# 0  7be6da0f9313404ca02afd000b0e787a  \
# 1  28cbde589b2b4954a5e39dd9df22624e
# 2  c12355d81050473e89f4163372441061
# 3  fcbd16768c584451912d7121a259ad9d
# 4  7a5fd04f52ef49298c35f0a86e614a4d
#
#                                                title Unnamed: 28
# 0  Fertility app used by 500k women sold private ...         NaN
# 1  More and more tickets being sold online as Pow...         NaN
# 2  Rep. Fitzgerald to Newsmax: DirecTV Dropping N...         NaN
# 3     YouTube praises AI transformation at Brandcast         NaN
# 4  Apple's quarter eases concerns about mobile de...         NaN
#
# [5 rows x 29 columns]

# %%
# Define a function to adjust the date considering the new format
def adjust_date_with_timezone(date):
    # Parse the date string into a datetime object
    date_obj = datetime.fromisoformat(date)
    # Add one day if the time is later than 4 PM
    if date_obj.hour >= 16:
        date_obj += timedelta(days=1)
    # Return the adjusted date in 'yyyy-mm-dd' format
    return date_obj.strftime('%Y-%m-%d')

# Apply the function to the 'pubDate' column to create 'adjusted_date'
data['adjusted_date'] = data['pubDate'].apply(adjust_date_with_timezone)

data.head()

# Save the modified dataset to a new file named "adjusted_dataset.xlsx"
#output_file_path = 'adjusted_dataset.xlsx'
#data.to_excel(output_file_path, index=False)
# Out:
#    index                                    title & content
# 0  12024  Delays Won‚Äôt Hurt Japan‚Äôs First Ca...  \
# 1  20675  MetLife (MET) Could Be a Great Choice - Gettin...
# 2  33685  New York Cements Itself as the Gold Mining Cap...
# 3  12072  Shareholders v. Tesla, Nasdaq's diversity rule...
# 4  28164  CFOs Boost Currency Protections, Extend Hedge ...
#
#                                    sentiment_perigon
# 0  {'positive': 0.026093118, 'negative': 0.923414...  \
# 1  {'positive': 0.8553927, 'negative': 0.01334850...
# 2  {'positive': 0.46477953, 'negative': 0.0338994...
# 3  {'positive': 0.02043453, 'negative': 0.6323841...
# 4  {'positive': 0.031100325, 'negative': 0.955758...
#
#                                              summary
# 0  Osaka Governor Hirofumi Yoshimura said that th...  \
# 1  MetLife (MET) is a Finance stock that has seen...
# 2  This week, top-five producer AngloGold Ashanti...
# 3  \n\nThe case is In re Tesla Inc Securities Lit...
# 4  CFOs Boost Currency Protections, Extend Hedge ...
#
#                                          description Ticker
# 0  Years of delay to plans for Japan‚Äôs firs...    MGM  \
# 1  Dividends are one of the best benefits to bein...    MET
# 2  (Bloomberg) -- The momentum has been building ...    NEM
# 3  Some of the biggest securities cases of 2023 a...   NDAQ
# 4  Coca-Cola, Kimberly-Clark and Prologis are amo...     KO
#
#                               Sector                        Industry
# 0                           Services                Casinos & Gaming  \
# 1                         Financials                       Insurance
# 2  Extractives & Minerals Processing                 Metals & Mining
# 3                         Financials  Security & Commodity Exchanges
# 4                    Food & Beverage         Non-Alcoholic Beverages
#
#                      Company
# 0  MGM Resorts International  \
# 1                Metlife Inc
# 2               Newmont Corp
# 3                 Nasdaq Inc
# 4               Coca-Cola Co
#
#                                                 SASB  ...
# 0  {'Internal Controls on Money Laundering': 'By ...  ...  \
# 1  {'Financed Emissions': 'Entities participating...  ...
# 2  {'Tailings Storage Facilities Management': 'Th...  ...
# 3  {'Managing Conflicts of Interest': 'Security a...  ...
# 4  {'Water Management': 'Water management relates...  ...
#
#                      pubDate
# 0  2023-05-18T21:25:29+00:00  \
# 1  2022-10-31T20:36:25+00:00
# 2  2023-02-08T22:16:21+00:00
# 3  2023-05-18T14:28:52+00:00
# 4  2023-05-04T23:39:33+00:00
#
#                                                  url
# 0  https://www.dailymail.co.uk/health/article-121...  \
# 1  https://nypost.com/2022/10/31/lottery-app-jack...
# 2  https://www.newsmax.com/newsmax-tv/fitzgerald-...
# 3  https://www.axios.com/pro/media-deals/2023/05/...
# 4  https://www.cnbc.com/2023/05/04/apples-q2-ease...
#
#                                             keywords              categories
# 0  [{'name': 'identifiable user health informatio...    [{'name': 'Health'}]  \
# 1  [{'name': 'ticket sales', 'weight': 0.10697382...                      []
# 2  [{'name': 'Newsmax', 'weight': 0.09317307}, {'...  [{'name': 'Politics'}]
# 3  [{'name': 'Google AI', 'weight': 0.09959001}, ...      [{'name': 'Tech'}]
# 4  [{'name': 'last year', 'weight': 0.0876609}, {...      [{'name': 'Tech'}]
#
#                                             entities
# 0  [{'data': 'Chinese', 'type': 'NORP', 'mentions...  \
# 1  [{'data': 'Powerball', 'type': 'WORK_OF_ART', ...
# 2  [{'data': 'Fitzgerald', 'type': 'PERSON', 'men...
# 3  [{'data': 'YouTube', 'type': 'ORG', 'mentions'...
# 4  [{'data': 'Apple', 'type': 'ORG', 'mentions': ...
#
#                                              content
# 0  A popular fertility app used by women to track...  \
# 1  You could win Monday night’s historic $1 bil...
# 2  Rep. Scott Fitzgerald, R-Wis., told Newsmax We...
# 3  YouTube has embraced AI for causing a massive ...
# 4  Apple (AAPL) posted a better-than-expected Mar...
#
#                           articleId
# 0  7be6da0f9313404ca02afd000b0e787a  \
# 1  28cbde589b2b4954a5e39dd9df22624e
# 2  c12355d81050473e89f4163372441061
# 3  fcbd16768c584451912d7121a259ad9d
# 4  7a5fd04f52ef49298c35f0a86e614a4d
#
#                                                title Unnamed: 28 adjusted_date
# 0  Fertility app used by 500k women sold private ...         NaN    2023-05-19
# 1  More and more tickets being sold online as Pow...         NaN    2022-11-01
# 2  Rep. Fitzgerald to Newsmax: DirecTV Dropping N...         NaN    2023-02-09
# 3     YouTube praises AI transformation at Brandcast         NaN    2023-05-18
# 4  Apple's quarter eases concerns about mobile de...         NaN    2023-05-05
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Article Published Frequencies Associated with top 40 companies

# %%
# Load the dataset
file_path = 'finished_annotation_5.2k.xlsx'
data = pd.read_excel(file_path)

# Count the frequency of each unique ticker
ticker_counts = data['Ticker'].value_counts()

# Selecting the top 40 most frequent tickers
top_40_tickers = ticker_counts.head(40)


# Plotting the top 40 tickers
plt.figure(figsize=(12, 8))
top_40_tickers.plot(kind='bar')
plt.title('Top 40 Ticker Symbols by Frequency')
plt.xlabel('Ticker Symbol')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
# Function to determine the highest sentiment category in 'sentiment_perigon'
def get_highest_sentiment(sentiment_dict):
    if isinstance(sentiment_dict, str):
        # Convert string representation to dictionary
        sentiment_dict = eval(sentiment_dict)
    if not isinstance(sentiment_dict, dict):
        return None
    return max(sentiment_dict, key=sentiment_dict.get)

# Apply the function to get the highest sentiment for each row in 'sentiment_perigon'
data['highest_sentiment'] = data['sentiment_perigon'].apply(get_highest_sentiment)

# Count the frequency of each unique ticker
ticker_counts = data['Ticker'].value_counts()

# Selecting the top 40 most frequent tickers
top_40_tickers = ticker_counts.head(40)

# Group by 'Ticker' and 'highest_sentiment', then count occurrences
sentiment_counts = data.groupby(['Ticker', 'highest_sentiment']).size().unstack(fill_value=0)

# Filtering to include only the top 40 tickers
top_40_sentiment_counts = sentiment_counts.loc[top_40_tickers.index]

# Plotting the stacked bar chart for the top 40 tickers
plt.figure(figsize=(15, 10))
top_40_sentiment_counts.plot(kind='bar', stacked=True, ax=plt.gca())
plt.title('Sentiment Distribution for Top 40 Ticker Symbols')
plt.xlabel('Ticker Symbol')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.legend(title='Sentiment')
plt.show()

# %% [markdown]
# ### Ticker by industry

# %%
# Count how many times each Sector has been mentioned
sector_counts = data['Sector'].value_counts()

# Create a bar chart for the Sector counts
plt.figure(figsize=(10,8))
sector_counts.plot(kind='bar')
plt.title('Number of Mentions per Sector')
plt.xlabel('Sector')
plt.ylabel('Number of Mentions')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlapping

# %% [markdown]
# ### Perentage of human_label matches with perigon

# %%
# Filtering out rows where 'human_label_sentiment' is 'No'
filtered_data = data[data['human_label_sentiment'] != 'No']

# Function to determine the highest sentiment category in 'sentiment_perigon'
def get_highest_sentiment(sentiment_dict):
    if isinstance(sentiment_dict, str):
        # Convert string representation to dictionary
        sentiment_dict = eval(sentiment_dict)
    if not isinstance(sentiment_dict, dict):
        return None
    return max(sentiment_dict, key=sentiment_dict.get)

# Applying the function to get the highest sentiment for each row in 'sentiment_perigon'
filtered_data['predicted_sentiment'] = filtered_data['sentiment_perigon'].apply(get_highest_sentiment)


# Function to match sentiments including 'Neutral'
def match_all_sentiments(perigon_sentiment, human_label):
    return (perigon_sentiment == 'positive' and human_label == 'Positive') or \
           (perigon_sentiment == 'negative' and human_label == 'Negative') or \
           (perigon_sentiment == 'neutral' and human_label == 'Neutral')

# Applying the matching criteria for all sentiment categories
filtered_data['is_match_all'] = filtered_data.apply(
    lambda row: match_all_sentiments(row['predicted_sentiment'], row['human_label_sentiment']), axis=1)

# Calculating the accuracy
correct_matches_all = filtered_data['is_match_all'].sum()
total = len(filtered_data)
accuracy_all_categories = correct_matches_all / total if total > 0 else 0

print(accuracy_all_categories)

filtered_data.head()
# Out:
# 0.5573221757322175
# /var/folders/f3/vz1sy2ys7gqd088dkmc5v9cw0000gn/T/ipykernel_91517/3867891901.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['predicted_sentiment'] = filtered_data['sentiment_perigon'].apply(get_highest_sentiment)
# /var/folders/f3/vz1sy2ys7gqd088dkmc5v9cw0000gn/T/ipykernel_91517/3867891901.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['is_match_all'] = filtered_data.apply(
#    index                                    title & content
# 3  12072  Shareholders v. Tesla, Nasdaq's diversity rule...  \
# 5  17931  Robert Half Named One of Barron's Most Sustain...
# 6  15389  The new electric USPS mail truck is America‚...
# 8  10731  FedEx closing more locations, planning to furl...
# 9   7801  FedEx Parks Planes, Maersk Cancels Sails: Worl...
#
#                                    sentiment_perigon
# 3  {'positive': 0.02043453, 'negative': 0.6323841...  \
# 5  {'positive': 0.22606649, 'negative': 0.0087869...
# 6  {'positive': 0.04448583, 'negative': 0.6695711...
# 8  {'positive': 0.02241792, 'negative': 0.9375396...
# 9  {'positive': 0.0276921, 'negative': 0.91408736...
#
#                                              summary
# 3  \n\nThe case is In re Tesla Inc Securities Lit...  \
# 5  Robert Half (NYSE: RHI) has been named one of ...
# 6  The $9.6 billion investment for mail trucks an...
# 8  FedEx announced on Monday that it will close 2...
# 9  Economic storm clouds are gathering worldwide ...
#
#                                          description Ticker          Sector
# 3  Some of the biggest securities cases of 2023 a...   NDAQ      Financials  \
# 5  Global talent solutions and business consultin...    RHI        Services
# 6  A new fleet of electric mail trucks heralds th...    UPS  Transportation
# 8  FedEx announced on Monday that it will close 2...    FDX  Transportation
# 9  FedEx Parks Planes, Maersk Cancels Sails: Worl...    FDX  Transportation
#
#                              Industry                      Company
# 3      Security & Commodity Exchanges                   Nasdaq Inc  \
# 5  Professional & Commercial Services              Robert Half Inc
# 6             Air Freight & Logistics  United Parcel Service Inc B
# 8             Air Freight & Logistics                   FedEx Corp
# 9             Air Freight & Logistics                   FedEx Corp
#
#                                                 SASB  ...
# 3  {'Managing Conflicts of Interest': 'Security a...  ...  \
# 5  {'Professional Integrity': 'The business model...  ...
# 6  {'Greenhouse Gas Emissions': 'Air Freight & Lo...  ...
# 8  {'Greenhouse Gas Emissions': 'Air Freight & Lo...  ...
# 9  {'Greenhouse Gas Emissions': 'Air Freight & Lo...  ...
#
#                                             keywords               categories
# 3  [{'name': 'Google AI', 'weight': 0.09959001}, ...       [{'name': 'Tech'}]  \
# 5  [{'name': 'leggings', 'weight': 0.08487634}, {...  [{'name': 'Lifestyle'}]
# 6  [{'name': 'last year', 'weight': 0.08339562}, ...    [{'name': 'Finance'}]
# 8  [{'name': 'AI models', 'weight': 0.13278106}, ...       [{'name': 'Tech'}]
# 9  [{'name': 'Available Updates', 'weight': 0.093...       [{'name': 'Tech'}]
#
#                                             entities
# 3  [{'data': 'YouTube', 'type': 'ORG', 'mentions'...  \
# 5  [{'data': 'the Dokotoo Tunic Top', 'type': 'PR...
# 6  [{'data': 'US', 'type': 'GPE', 'mentions': 2},...
# 8  [{'data': 'Nick Clegg', 'type': 'PERSON', 'men...
# 9  [{'data': 'The New Year', 'type': 'EVENT', 'me...
#
#                                              content
# 3  YouTube has embraced AI for causing a massive ...  \
# 5  It's (finally) June, not exactly summer yet bu...
# 6  (Bloomberg) -- Mortgage rates in the US rose f...
# 8  Nick Clegg has defended the release of an open...
# 9  The New Year is a great time to ensure that al...
#
#                           articleId
# 3  fcbd16768c584451912d7121a259ad9d  \
# 5  70f468d08f314bb1866b8b8943f5c24d
# 6  9d91fc353772453697b247bc4c80c2a3
# 8  3cb0ea7cb1cb40608c1cfc1e172ebc3e
# 9  8fa35beec4c8419cba9c5bcc287554c8
#
#                                                title Unnamed: 28
# 3     YouTube praises AI transformation at Brandcast         NaN  \
# 5  ‘Covers your tummy and looks great’: Shopp...         NaN
# 6  Mortgage Rates in the US Rise for the First Ti...         NaN
# 8  Nick Clegg defends release of open-source AI m...         NaN
# 9  Start your year off by making sure all your de...         NaN
#
#   adjusted_date predicted_sentiment is_match_all
# 3    2023-05-18            negative        False
# 5    2023-06-08             neutral        False
# 6    2022-12-30            negative        False
# 8    2023-07-19            negative         True
# 9    2023-01-04            negative         True
#
# [5 rows x 32 columns]
